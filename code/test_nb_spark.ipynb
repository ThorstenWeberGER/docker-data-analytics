# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit  

spark = SparkSession.builder.appName("DataFrameExample").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/29 17:31:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data = [("Alice", 34), ("Bob", 45), ("Cathy", 29)]
columns = ["Name", "Age"]

df = spark.createDataFrame(data, columns)
df = df.withColumn("Country", lit("USA"))
df = df.withColumn("AgePlusTen", col("Age") + 10)

df.show()
# Out:
# +-----+---+-------+----------+
# | Name|Age|Country|AgePlusTen|
# +-----+---+-------+----------+
# |Alice| 34|    USA|        44|
# |  Bob| 45|    USA|        55|
# |Cathy| 29|    USA|        39|
# +-----+---+-------+----------+

# %%
import matplotlib.pyplot as plt

ages = [row['Age'] for row in df.collect()]
plt.hist(ages, bins=5, color='blue', alpha=0.7)
plt.title('Age Distribution')
plt.show()
